# %% [markdown]
# # Visualisation of Road Traffic Deaths of Different Countries in 2013

# %% [markdown]
# Phase 3: In this Phase I will findout indivisual country rank in each type of Road Traffic Death. For Example Bhuthan comes first in Four Wheelers Death rate. This ranking will be also used to plot a TreeMap using D3js along with GeoMap plotting

# %% [markdown]
# This will be end of cleaning and preprocessing of Data using python, Visualization will be done using D3js.

# %%
import numpy as np 
import pandas as pd

# %%
finalMergedDataV2 = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\final_Data_V1.csv",encoding="ISO-8859-1")

# %%
finalMergedDataV2.head()
# Out:
#     code      Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 0  ASAFG  Afghanistan            0.0           0.0       0.0          0.0
# 1  EUALB      Albania           50.8          13.2       4.1         31.2
# 2  AFDZA      Algeria            0.0           0.0       0.0          0.0
# 3  EUAND      Andorra            0.0          50.0       0.0         50.0
# 4  AFAGO       Angola            0.0           1.9       0.0         35.4
#
#    Others  Estimated road traffic death rate per 100 000 population
# 0     0.0                                               15.5
# 1     0.7                                               15.1
# 2     0.0                                               23.8
# 3     0.0                                                7.6
# 4    62.7                                               26.9

# %% [markdown]
# Sorting Each column which will be used to create rank in future

# %%
fourWheelers = finalMergedDataV2.sort_values(by='Four-Wheelers',ascending=False )

# %%
twoWheelers = finalMergedDataV2.sort_values(by='Two-Wheelers',ascending=False )

# %%
cyclists = finalMergedDataV2.sort_values(by='Cyclists',ascending=False )

# %%
pedestrians = finalMergedDataV2.sort_values(by='Pedestrians',ascending=False )

# %%
others = finalMergedDataV2.sort_values(by='Others',ascending=False )

# %%
#Bhutan tops the list for Four Wheelers
fourWheelers.head()
# Out:
#       code       Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 15   ASBTN        Bhutan           94.9           1.7       0.0          3.4
# 5    SAARG     Argentina           88.0           0.0       2.0         10.1
# 61   EUISL       Iceland           80.0           6.7       0.0          6.7
# 151  ASTKM  Turkmenistan           74.7           0.0       1.9         23.4
# 116  ASQAT         Qatar           71.6           0.0       0.0         28.4
#
#      Others  Estimated road traffic death rate per 100 000 population
# 15      0.0                                               15.1
# 5       0.0                                               13.6
# 61      6.7                                                4.6
# 151     0.0                                               17.4
# 116     0.0                                               15.2

# %%
twoWheelers.head()
# Out:
#       code                           Country  Four-Wheelers  Two-Wheelers  \
# 123  EUSMR                        San Marino            0.0         100.0
# 145  ASTHA                          Thailand           13.0          72.8
# 25   ASKHM                          Cambodia            8.5          70.4
# 76   ASLAO  Lao People's Democratic Republic           18.7          66.9
# 90   OCMHL                  Marshall Islands           33.3          66.7
#
#      Cyclists  Pedestrians  Others  \
# 123       0.0          0.0     0.0
# 145       2.3          8.1     3.8
# 25        2.3         12.7     6.1
# 76        2.7          9.6     2.1
# 90        0.0          0.0     0.0
#
#      Estimated road traffic death rate per 100 000 population
# 123                                                3.2
# 145                                               36.2
# 25                                                17.4
# 76                                                14.3
# ...

# %%
cyclists.head()
# Out:
#       code      Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 73   OCKIR     Kiribati            0.0           0.0      33.3         66.7
# 102  EUNLD  Netherlands           36.5          13.5      32.3          9.8
# 40   EUDNK      Denmark           50.3          13.6      17.3         17.8
# 85   AFMWI       Malawi           32.5           1.3      17.2         49.1
# 87   ASMDV     Maldives           16.7          16.7      16.7         33.3
#
#      Others  Estimated road traffic death rate per 100 000 population
# 73      0.0                                                2.9
# 102     7.9                                                3.4
# 40      1.0                                                3.5
# 85      0.0                                               35.0
# 87     16.7                                                3.5

# %%
pedestrians.head()
# Out:
#       code     Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 109  OCPLW       Palau            0.0           0.0       0.0        100.0
# 122  OCWSM       Samoa            0.0           0.0       0.0         76.5
# 128  AFSYC  Seychelles           25.0           0.0       0.0         75.0
# 73   OCKIR    Kiribati            0.0           0.0      33.3         66.7
# 48   OCFJI        Fiji           39.0           0.0       2.4         58.5
#
#      Others  Estimated road traffic death rate per 100 000 population
# 109     0.0                                                4.8
# 122    23.5                                               15.8
# 128     0.0                                                8.6
# 73      0.0                                                2.9
# 48      0.0                                                5.8

# %%
others.head()
# Out:
#       code  Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 112  SAPER     Peru            6.9           1.0       0.3         23.3
# 139  AFSDN    Sudan            0.0           0.0       0.0         33.4
# 4    AFAGO   Angola            0.0           1.9       0.0         35.4
# 42   SAECU  Ecuador            2.2           6.9       0.5         30.0
# 78   ASLBN  Lebanon            0.0           0.0       0.0         43.3
#
#      Others  Estimated road traffic death rate per 100 000 population
# 112    68.4                                               13.9
# 139    66.6                                               24.3
# 4      62.7                                               26.9
# 42     60.3                                               20.1
# 78     56.7                                               22.6

# %% [markdown]
# Now I will write this information to indivisual files and merge all files together to get the ranking of each countries.

# %%
fourWheelers['Four_Wheelers_Rank'] =""
fourWheelers.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\four1.csv", encoding="ISO-8859-1")

# %%
twoWheelers['Two_Wheelers_Rank'] =""
twoWheelers.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\two1.csv", encoding="ISO-8859-1")

# %%
cyclists['Cyclists_Rank'] =""
cyclists.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\cycle1.csv", encoding="ISO-8859-1")

# %%
pedestrians['Pedestrians_Rank'] =""
pedestrians.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\ped1.csv", encoding="ISO-8859-1")

# %%
others['Others_Rank'] =""
others.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\others1.csv", encoding="ISO-8859-1")

# %%
fourWheelers = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\four1.csv", encoding="ISO-8859-1")

# %%
twoWheelers = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\two1.csv", encoding="ISO-8859-1")

# %%
cyclists = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\cycle1.csv", encoding="ISO-8859-1")

# %%
pedestrians = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\ped1.csv", encoding="ISO-8859-1")

# %%
others = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\others1.csv", encoding="ISO-8859-1")

# %%
fourWheelers.head()
# Out:
#     code       Country  Four-Wheelers  Two-Wheelers  Cyclists  Pedestrians  \
# 0  ASBTN        Bhutan           94.9           1.7       0.0          3.4
# 1  SAARG     Argentina           88.0           0.0       2.0         10.1
# 2  EUISL       Iceland           80.0           6.7       0.0          6.7
# 3  ASTKM  Turkmenistan           74.7           0.0       1.9         23.4
# 4  ASQAT         Qatar           71.6           0.0       0.0         28.4
#
#    Others  Estimated road traffic death rate per 100 000 population  \
# 0     0.0                                               15.1
# 1     0.0                                               13.6
# 2     6.7                                                4.6
# 3     0.0                                               17.4
# 4     0.0                                               15.2
#
#    Four_Wheelers_Rank
# 0                   1
# 1                   2
# 2                   3
# 3                   4
# ...

# %%
mer1 = fourWheelers.merge(twoWheelers,left_on='Country',right_on='Country',how='left')

# %%
mer1.head()
# Out:
#   code_x       Country  Four-Wheelers_x  Two-Wheelers_x  Cyclists_x  \
# 0  ASBTN        Bhutan             94.9             1.7         0.0
# 1  SAARG     Argentina             88.0             0.0         2.0
# 2  EUISL       Iceland             80.0             6.7         0.0
# 3  ASTKM  Turkmenistan             74.7             0.0         1.9
# 4  ASQAT         Qatar             71.6             0.0         0.0
#
#    Pedestrians_x  Others_x  \
# 0            3.4       0.0
# 1           10.1       0.0
# 2            6.7       6.7
# 3           23.4       0.0
# 4           28.4       0.0
#
#    Estimated road traffic death rate per 100 000 population_x  \
# 0                                               15.1
# 1                                               13.6
# 2                                                4.6
# 3                                               17.4
# 4                                               15.2
#
# ...

# %%
mer2 = mer1.merge(cyclists,left_on='Country',right_on='Country',how='left')

# %%
mer3 = mer2.merge(pedestrians,left_on='Country',right_on='Country',how='left')

# %%
mer4 = mer3.merge(others,left_on='Country',right_on='Country',how='left')

# %%
mer4.head()
# Out:
#   code_x       Country  Four-Wheelers_x  Two-Wheelers_x  Cyclists_x  \
# 0  ASBTN        Bhutan             94.9             1.7         0.0
# 1  SAARG     Argentina             88.0             0.0         2.0
# 2  EUISL       Iceland             80.0             6.7         0.0
# 3  ASTKM  Turkmenistan             74.7             0.0         1.9
# 4  ASQAT         Qatar             71.6             0.0         0.0
#
#    Pedestrians_x  Others_x  \
# 0            3.4       0.0
# 1           10.1       0.0
# 2            6.7       6.7
# 3           23.4       0.0
# 4           28.4       0.0
#
#    Estimated road traffic death rate per 100 000 population_x  \
# 0                                               15.1
# 1                                               13.6
# 2                                                4.6
# 3                                               17.4
# 4                                               15.2
#
#    Four_Wheelers_Rank code_y     ...       \
# ...

# %%
rankingData=mer4.to_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\rankingV2.csv",encoding="ISO-8859-1")

# %%
finalDataSet = pd.read_csv(r"C:\Users\Salman\Desktop\SEM1\CA682-Data Management & Visualisation\salman\CA682-Assignment\Datasets\converted\rankingV2.csv",encoding="ISO-8859-1")

# %%
finalDataSet
# Out:
#       code                                Country  Four-Wheelers  \
# 0    asbtn                                 Bhutan           94.9
# 1    saarg                              Argentina           88.0
# 2    euisl                                Iceland           80.0
# 3    astkm                           Turkmenistan           74.7
# 4    asqat                                  Qatar           71.6
# 5    afcod       Democratic Republic of the Congo           70.9
# 6    aflby                                  Libya           70.8
# 7    afbwa                               Botswana           67.6
# 8    askgz                             Kyrgyzstan           67.3
# 9    afner                                  Niger           67.0
# 10   eulux                             Luxembourg           66.7
# 11   nacan                                 Canada           66.6
# 12   afzaf                           South Africa           66.6
# ...

# %% [markdown]
# # This will be my Final Dataset which will be used for Visualization. I will be creating 5 different treemaps for indivisual country ranking and a final geoMap. I will be using HTML, Javascript, D3js in Sublime text editor.
